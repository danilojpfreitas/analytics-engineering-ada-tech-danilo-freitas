# %% [markdown]
# ## Módulo: Analytics Engineering
#
# ## Projeto: Engenharia de Dados e Garantia de Qualidade no Conjunto de Dados do Airbnb no Rio de Janeiro.

# %% [markdown]
# #### Introdução à Base de Dados do Airbnb
#
# O conjunto de dados "Inside Airbnb", disponível no website "http://insideairbnb.com/", é uma valiosa fonte de informações sobre listagens de hospedagem, avaliações de hóspedes e disponibilidade de calendário em várias cidades ao redor do mundo, incluindo o Rio de Janeiro. Antes de prosseguirmos com a engenharia de dados, é importante entender os principais componentes deste conjunto de dados:
#
# 1. **Listing (Listagem):** Este conjunto de dados contém informações detalhadas sobre as propriedades listadas no Airbnb. Cada registro representa uma listagem individual e inclui informações como o tipo de propriedade, preço, localização, número de quartos, comodidades oferecidas e muito mais.
#
# 2. **Reviews (Avaliações):** O conjunto de dados de avaliações contém informações sobre as avaliações feitas por hóspedes que ficaram nas propriedades listadas. Ele inclui dados como a data da avaliação, o identificador da propriedade, os comentários escritos pelos hóspedes, e outras informações.
#
# 3. **Calendar (Calendário):** Este conjunto de dados contém informações sobre a disponibilidade das propriedades ao longo do tempo. Ele lista as datas em que as propriedades estão disponíveis para reserva, bem como os preços para cada data.
#
# O dicionário dos dados também está disponível no website: "http://insideairbnb.com/".
#
# #### Passos do Projeto
#
# 1. **Aquisição de Dados e Armazenamento de Dados em PostgreSQL - Camada Bronze**
#    - Baixe o conjunto de dados "Inside Airbnb" do Rio de Janeiro da fonte oficial (http://insideairbnb.com/) e promova uma estruturação simples nos dados.
#    - Crie um banco de dados PostgreSQL para armazenar os dados brutos das 3 tabelas ("Listing", "Reviews" e Calendar") na camada "bronze".
#
# <br>
#
# 2. **Data Clean - Camada Silver:**
#    - Identifique e lide com valores ausentes, duplicatas e outliers nos dados brutos da camada "bronze".
#    - Padronize e limpe os nomes das colunas, convertendo-os em um formato consistente.
#    - Realize uma limpeza textual em campos, como descrições de propriedades, removendo caracteres especiais e erros de digitação.
#
# <br>
#
# 3. **Data Quality - Camada Silver:**
#    - Defina métricas de qualidade de dados, como integridade, precisão e consistência para os dados da camada "bronze".
#    - Implemente verificações para garantir que os dados da camada "silver" estejam em conformidade com essas métricas.
#    - Estabeleça um sistema de monitoramento contínuo da qualidade dos dados da camada "silver".
#
# <br>
#
# 4. **Testes de Qualidade - Camada Silver:**
#    - Utilize a biblioteca Great Expectations para criar testes de qualidade automatizados que verifiquem as expectativas definidas para os dados da camada "silver".
#    - Desenvolva testes que assegurem que os dados da camada "silver" atendam às regras de negócios e aos requisitos de qualidade.
#
# <br>
#
# 5. **Transformação de Dados com dbt - Camada Silver:**
#    - Utilize a ferramenta dbt para criar a camada "silver" de dados, realizando transformações e preparando os dados da camada em questão.
#    - Mantenha um controle de versão dos modelos dbt relacionados à camada "silver" e automatize a execução das transformações.
#
# <br>
#
# 6. **Armazenamento de Dados em PostgreSQL - Camada Silver:**
#    - Armazene os dados da camada "silver" no mesmo banco de dados PostgreSQL.
#    - Estabeleça conexões entre o dbt e o PostgreSQL para carregar os dados transformados da camada "silver" no banco.
#
# <br>
#
# 7. **Validação de Expectativas com Great Expectations - Camada Silver:**
#    - Implemente validações adicionais usando Great Expectations nas camadas de dados da camada "silver".
#    - Monitore a qualidade dos dados da camada "silver" após cada transformação e ajuste os testes de acordo.
#
# <br>
#
# 8. **Transformação de Dados com dbt - Camada Gold:**
#    - Utilize o dbt para criar a camada "gold" de dados, aplicando agregações especializadas, como médias de preços por propriedade, por período, e outras agregações especializadas.
#    - Mantenha um controle de versão dos modelos dbt relacionados à camada "gold" e automatize a execução das transformações.
#    - Armazene os dados da camada "gold" no mesmo banco de dados PostgreSQL, mantendo a estrutura de dados otimizada para consultas analíticas.
#
# <br>
#
#  9. **Apresentação e Discussão:**
#     - Apresente os resultados do projeto para a turma, enfatizando os aspectos de engenharia de dados, qualidade de dados e uso de ferramentas como dbt, Great Expectations e o armazenamento em um banco de dados PostgreSQL nas camadas "bronze", "silver" e "gold".

# %% [markdown]
# # Etapas

# %% [markdown]
# **Aquisição de Dados e Armazenamento de Dados em PostgreSQL - Camada Bronze**
#    - Baixe o conjunto de dados "Inside Airbnb" do Rio de Janeiro da fonte oficial (http://insideairbnb.com/) e promova uma estruturação simples nos dados.
#    - Crie um banco de dados PostgreSQL para armazenar os dados brutos das 3 tabelas ("Listing", "Reviews" e Calendar") na camada "bronze".

# %% [markdown]
# ##### Dependências

# %%
# !pip install pandas
# !pip install sqlalchemy
# !pip install pymysql
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: pandas in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/danilojpfreitas/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /home/danilojpfreitas/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: sqlalchemy in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (from sqlalchemy) (2.0.1)
# Requirement already satisfied: pymysql in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: psycopg2-binary in /home/danilojpfreitas/anaconda3/lib/python3.10/site-packages (2.9.9)

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ##### Importando os dados como DataFrame Pandas

# %%
calendar = pd.read_csv('data_csv/calendar.csv')
listings = pd.read_csv('data_csv/listings.csv')
reviews = pd.read_csv('data_csv/reviews.csv')

# %%
calendar.head(5)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-09-23         f  $265.00        $265.00             5.0
# 1       17878  2023-09-24         t  $265.00        $265.00             5.0
# 2       17878  2023-09-25         f  $290.00        $290.00             5.0
# 3       17878  2023-09-26         f  $290.00        $290.00             5.0
# 4       17878  2023-09-27         f  $290.00        $290.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0

# %%
listings.head(5)
# Out:
#       id                                               name  host_id  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...    68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...   102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...   153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...    70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...   222884
#
#                   host_name  neighbourhood_group neighbourhood  latitude  \
# 0                  Matthias                  NaN    Copacabana -22.96599
# 1                   Viviane                  NaN    Copacabana -22.97735
# 2  Patricia Miranda & Paulo                  NaN    Copacabana -22.98107
# 3                   Goitaca                  NaN       Ipanema -22.98591
# 4                    Marcio                  NaN    Copacabana -22.96574
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -43.17940  Entire home/apt    279               5                301
# 1  -43.19105  Entire home/apt    330               2                272
# 2  -43.19136  Entire home/apt    192               3                446
# 3  -43.20302  Entire home/apt   3448               2                152
# 4  -43.17514  Entire home/apt    703               3                 20
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-09-11               1.87                               1
# 1  2023-09-07               1.68                               1
# 2  2023-09-11               2.82                               1
# 3  2023-09-10               0.99                               9
# 4  2023-09-10               0.20                               1
#
#    availability_365  number_of_reviews_ltm  license
# 0               265                     25      NaN
# 1               203                     24      NaN
# 2                46                     37      NaN
# 3               306                     30      NaN
# 4               307                     12      NaN

# %%
reviews.head(5)
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0      231497  726625  2011-11-17      1356783         Jenny
# 1       17878   64852  2010-07-15       135370           Tia
# 2       17878   76744  2010-08-11        10206          Mimi
# 3       17878   91074  2010-09-06        80253           Jan
# 4       17878  137528  2010-11-12       230449         Orene
#
#                                             comments
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...

# %% [markdown]
# ##### Importando DataFrame para o PostgreSQL

# %%
user = 'postgres'
password = 'ada_postgres_1009'
host = 'database-ada-1009.clzgkgrmzmzh.us-east-1.rds.amazonaws.com'
port = '5432'
database = 'postgres'
schema = 'raw'

# %%
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')

# %% [markdown]
# calendar

# %%
raw_calendar_table = 'danilo_freitas_raw_calendar'

# %%
calendar.to_sql(name=raw_calendar_table, con=engine, if_exists='replace', index=False, schema=schema)

# %% [markdown]
# listings

# %%
raw_listings_table = 'danilo_freitas_raw_listings'

# %%
listings.to_sql(name=raw_listings_table, con=engine, if_exists='replace', index=False, schema=schema)
# Out:
# 964

# %% [markdown]
# reviews

# %%
raw_reviews_table = 'danilo_freitas_raw_reviews'

# %%
reviews.to_sql(name=raw_reviews_table, con=engine, if_exists='replace', index=False, schema=schema)
# Out:
# 307

# %% [markdown]
# **Data Clean - Camada Silver:**
#    - Identifique e lide com valores ausentes, duplicatas e outliers nos dados brutos da camada "bronze".
#    - Padronize e limpe os nomes das colunas, convertendo-os em um formato consistente.
#    - Realize uma limpeza textual em campos, como descrições de propriedades, removendo caracteres especiais e erros de digitação.

# %% [markdown]
# ##### Leitura do raw data do banco de dados

# %%
db_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "ada_postgres_1009",
    "host": "database-ada-1009.clzgkgrmzmzh.us-east-1.rds.amazonaws.com",  
    "port": "5432"  
}

# %%
conn = psycopg2.connect(**db_params)

# %% [markdown]
# ##### calendar

# %%
calendar_raw = "SELECT * FROM raw.danilo_freitas_raw_calendar;"

# %%
calendar_raw_df = pd.read_sql_query(calendar_raw, conn)
# Out:
# /tmp/ipykernel_26692/1951227670.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   calendar_raw_df = pd.read_sql_query(calendar_raw, conn)

# %%
calendar_raw_df.head(5)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-09-23         f  $265.00        $265.00             5.0
# 1       17878  2023-09-24         t  $265.00        $265.00             5.0
# 2       17878  2023-09-25         f  $290.00        $290.00             5.0
# 3       17878  2023-09-26         f  $290.00        $290.00             5.0
# 4       17878  2023-09-27         f  $290.00        $290.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0

# %% [markdown]
# listings

# %%
listings_raw = "SELECT * FROM raw.danilo_freitas_raw_listings;"

# %%
listings_raw_df = pd.read_sql_query(listings_raw, conn)
# Out:
# /tmp/ipykernel_26692/959584078.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   listings_raw_df = pd.read_sql_query(listings_raw, conn)

# %%
listings_raw_df.head(5)
# Out:
#       id                                               name  host_id  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...    68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...   102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...   153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...    70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...   222884
#
#                   host_name neighbourhood_group neighbourhood  latitude  \
# 0                  Matthias                None    Copacabana -22.96599
# 1                   Viviane                None    Copacabana -22.97735
# 2  Patricia Miranda & Paulo                None    Copacabana -22.98107
# 3                   Goitaca                None       Ipanema -22.98591
# 4                    Marcio                None    Copacabana -22.96574
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -43.17940  Entire home/apt    279               5                301
# 1  -43.19105  Entire home/apt    330               2                272
# 2  -43.19136  Entire home/apt    192               3                446
# 3  -43.20302  Entire home/apt   3448               2                152
# 4  -43.17514  Entire home/apt    703               3                 20
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-09-11               1.87                               1
# 1  2023-09-07               1.68                               1
# 2  2023-09-11               2.82                               1
# 3  2023-09-10               0.99                               9
# 4  2023-09-10               0.20                               1
#
#    availability_365  number_of_reviews_ltm license
# 0               265                     25    None
# 1               203                     24    None
# 2                46                     37    None
# 3               306                     30    None
# 4               307                     12    None

# %% [markdown]
# reviews

# %%
reviews_raw = "SELECT * FROM raw.danilo_freitas_raw_reviews;"

# %%
reviews_raw_df = pd.read_sql_query(reviews_raw, conn)
# Out:
# /tmp/ipykernel_26692/4107597973.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   reviews_raw_df = pd.read_sql_query(reviews_raw, conn)

# %%
reviews_raw_df.head(5)
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0      231497  726625  2011-11-17      1356783         Jenny
# 1       17878   64852  2010-07-15       135370           Tia
# 2       17878   76744  2010-08-11        10206          Mimi
# 3       17878   91074  2010-09-06        80253           Jan
# 4       17878  137528  2010-11-12       230449         Orene
#
#                                             comments
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...

# %% [markdown]
# ##### calendar

# %% [markdown]
#    - Identifique e lide com valores ausentes, duplicatas e outliers nos dados brutos da camada "bronze".

# %%
calendar_raw_df.isnull()
# Out:
#          listing_id   date  available  price  adjusted_price  minimum_nights  \
# 0             False  False      False  False           False           False
# 1             False  False      False  False           False           False
# 2             False  False      False  False           False           False
# 3             False  False      False  False           False           False
# 4             False  False      False  False           False           False
# ...             ...    ...        ...    ...             ...             ...
# 2983995       False  False      False  False           False           False
# 2983996       False  False      False  False           False           False
# 2983997       False  False      False  False           False           False
# 2983998       False  False      False  False           False           False
# 2983999       False  False      False  False           False           False
#
#          maximum_nights
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2983995           False
# 2983996           False
# 2983997           False
# 2983998           False
# 2983999           False
#
# [2984000 rows x 7 columns]

# %%
num_nulos_por_coluna = calendar_raw_df.isnull().sum()
print(num_nulos_por_coluna)
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    3
# maximum_nights    3
# dtype: int64

# %%
calendar_raw_df.drop_duplicates(inplace=True)

# %%
calendar_raw_df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2983995    False
# 2983996    False
# 2983997    False
# 2983998    False
# 2983999    False
# Length: 2984000, dtype: bool

# %%
calendar_raw_df.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  2.984000e+06    2.983997e+06    2.983997e+06
# mean   1.013328e+07    6.695479e+00    6.906041e+02
# std    6.270713e+06    2.605333e+01    5.177538e+02
# min    1.787800e+04    1.000000e+00    1.000000e+00
# 25%    3.183573e+06    2.000000e+00    6.000000e+01
# 50%    1.120795e+07    3.000000e+00    1.125000e+03
# 75%    1.421395e+07    5.000000e+00    1.125000e+03
# max    2.240569e+07    1.125000e+03    1.825000e+03

# %% [markdown]
# - Padronize e limpe os nomes das colunas, convertendo-os em um formato consistente.

# %%
calendar_raw_df.head(5)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-09-23         f  $265.00        $265.00             5.0
# 1       17878  2023-09-24         t  $265.00        $265.00             5.0
# 2       17878  2023-09-25         f  $290.00        $290.00             5.0
# 3       17878  2023-09-26         f  $290.00        $290.00             5.0
# 4       17878  2023-09-27         f  $290.00        $290.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0

# %%
calendar_raw_df.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price              object
# adjusted_price     object
# minimum_nights    float64
# maximum_nights    float64
# dtype: object

# %%
calendar_raw_df["date"] = pd.to_datetime(calendar_raw_df['date'])

# %%
new_name_columns = ['id_listing', 'data', 'disponibilidade', 'preco', 'preco_ajustado', 'minimo_noites', 'maximo_noites']

# %%
calendar_raw_df.columns = new_name_columns

# %%
calendar_raw_df.head(5)
# Out:
#    id_listing       data disponibilidade    preco preco_ajustado  \
# 0       17878 2023-09-23               f  $265.00        $265.00
# 1       17878 2023-09-24               t  $265.00        $265.00
# 2       17878 2023-09-25               f  $290.00        $290.00
# 3       17878 2023-09-26               f  $290.00        $290.00
# 4       17878 2023-09-27               f  $290.00        $290.00
#
#    minimo_noites  maximo_noites
# 0            5.0           28.0
# 1            5.0           28.0
# 2            5.0           28.0
# 3            5.0           28.0
# 4            5.0           28.0

# %% [markdown]
# - Realize uma limpeza textual em campos, como descrições de propriedades, removendo caracteres especiais e erros de digitação.

# %%
calendar_raw_df.head(50)
# Out:
#     id_listing       data disponibilidade    preco preco_ajustado  \
# 0        17878 2023-09-23               f  $265.00        $265.00
# 1        17878 2023-09-24               t  $265.00        $265.00
# 2        17878 2023-09-25               f  $290.00        $290.00
# 3        17878 2023-09-26               f  $290.00        $290.00
# 4        17878 2023-09-27               f  $290.00        $290.00
# 5        17878 2023-09-28               f  $290.00        $290.00
# 6        17878 2023-09-29               f  $290.00        $290.00
# 7        17878 2023-09-30               f  $290.00        $290.00
# 8        17878 2023-10-01               f  $290.00        $290.00
# 9        17878 2023-10-02               t  $290.00        $290.00
# 10       17878 2023-10-03               t  $290.00        $290.00
# 11       17878 2023-10-04               t  $290.00        $290.00
# 12       17878 2023-10-05               t  $290.00        $290.00
# 13       17878 2023-10-06               f  $290.00        $290.00
# 14       17878 2023-10-07               f  $290.00        $290.00
# 15       17878 2023-10-08               f  $290.00        $290.00
# 16       17878 2023-10-09               f  $290.00        $290.00
# 17       17878 2023-10-10               f  $290.00        $290.00
# 18       17878 2023-10-11               f  $290.00        $290.00
# 19       17878 2023-10-12               f  $290.00        $290.00
# 20       17878 2023-10-13               f  $290.00        $290.00
# 21       17878 2023-10-14               t  $350.00        $350.00
# 22       17878 2023-10-15               t  $350.00        $350.00
# 23       17878 2023-10-16               t  $350.00        $350.00
# 24       17878 2023-10-17               t  $350.00        $350.00
# 25       17878 2023-10-18               t  $350.00        $350.00
# 26       17878 2023-10-19               t  $350.00        $350.00
# 27       17878 2023-10-20               t  $350.00        $350.00
# 28       17878 2023-10-21               t  $350.00        $350.00
# 29       17878 2023-10-22               t  $350.00        $350.00
# 30       17878 2023-10-23               t  $350.00        $350.00
# 31       17878 2023-10-24               t  $350.00        $350.00
# 32       17878 2023-10-25               t  $350.00        $350.00
# 33       17878 2023-10-26               t  $350.00        $350.00
# 34       17878 2023-10-27               f  $350.00        $350.00
# 35       17878 2023-10-28               f  $350.00        $350.00
# 36       17878 2023-10-29               f  $350.00        $350.00
# 37       17878 2023-10-30               f  $350.00        $350.00
# 38       17878 2023-10-31               f  $350.00        $350.00
# 39       17878 2023-11-01               f  $350.00        $350.00
# 40       17878 2023-11-02               f  $350.00        $350.00
# 41       17878 2023-11-03               f  $350.00        $350.00
# 42       17878 2023-11-04               f  $350.00        $350.00
# 43       17878 2023-11-05               f  $350.00        $350.00
# 44       17878 2023-11-06               f  $350.00        $350.00
# 45       17878 2023-11-07               f  $350.00        $350.00
# 46       17878 2023-11-08               f  $350.00        $350.00
# 47       17878 2023-11-09               f  $350.00        $350.00
# 48       17878 2023-11-10               f  $350.00        $350.00
# 49       17878 2023-11-11               f  $350.00        $350.00
#
#     minimo_noites  maximo_noites
# 0             5.0           28.0
# 1             5.0           28.0
# 2             5.0           28.0
# 3             5.0           28.0
# 4             5.0           28.0
# 5             5.0           28.0
# 6             5.0           28.0
# 7             5.0           28.0
# 8             5.0           28.0
# 9             5.0           28.0
# 10            5.0           28.0
# 11            5.0           28.0
# 12            5.0           28.0
# 13            5.0           28.0
# 14            5.0           28.0
# 15            5.0           28.0
# 16            5.0           28.0
# 17            5.0           28.0
# 18            5.0           28.0
# 19            5.0           28.0
# 20            5.0           28.0
# 21            5.0           28.0
# 22            5.0           28.0
# 23            5.0           28.0
# 24            5.0           28.0
# 25            5.0           28.0
# 26            5.0           28.0
# 27            5.0           28.0
# 28            5.0           28.0
# 29            5.0           28.0
# 30            5.0           28.0
# 31            5.0           28.0
# 32            5.0           28.0
# 33            5.0           28.0
# 34            5.0           28.0
# 35            5.0           28.0
# 36            5.0           28.0
# 37            5.0           28.0
# 38            5.0           28.0
# 39            5.0           28.0
# 40            5.0           28.0
# 41            5.0           28.0
# 42            5.0           28.0
# 43            5.0           28.0
# 44            5.0           28.0
# 45            5.0           28.0
# 46            5.0           28.0
# 47            5.0           28.0
# 48            5.0           28.0
# 49            5.0           28.0

# %%
danilo_freitas_processing_calendar = "danilo_freitas_processing_calendar"
trusted = "trusted"

# %%
db_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "ada_postgres_1009",
    "host": "database-ada-1009.clzgkgrmzmzh.us-east-1.rds.amazonaws.com",  
    "port": "5432"  
}

# %%
engine = create_engine(f'postgresql+psycopg2://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{db_params["dbname"]}')

# %%
calendar.to_sql(danilo_freitas_processing_calendar, con=engine, schema=trusted, if_exists='replace', index=False)
# Out:
# O Kernel falhou ao executar o código na célula atual ou em uma célula anterior. Examine o código nas células para identificar uma possível causa da falha. Clique <a href="https://aka.ms/vscodeJupyterKernelCrash">aqui</a> para obter mais informações. Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %% [markdown]
# ##### listings

# %% [markdown]
#    - Identifique e lide com valores ausentes, duplicatas e outliers nos dados brutos da camada "bronze".

# %%
listings_raw_df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                 True          False
# 1      False  False    False      False                 True          False
# 2      False  False    False      False                 True          False
# 3      False  False    False      False                 True          False
# 4      False  False    False      False                 True          False
# ...      ...    ...      ...        ...                  ...            ...
# 31959  False  False    False      False                 True          False
# 31960  False  False    False      False                 True          False
# 31961  False  False    False      False                 True          False
# 31962  False  False    False      False                 True          False
# 31963  False  False    False      False                 True          False
#
#        latitude  longitude  room_type  price  minimum_nights  \
# 0         False      False      False  False           False
# 1         False      False      False  False           False
# 2         False      False      False  False           False
# 3         False      False      False  False           False
# 4         False      False      False  False           False
# ...         ...        ...        ...    ...             ...
# 31959     False      False      False  False           False
# 31960     False      False      False  False           False
# 31961     False      False      False  False           False
# 31962     False      False      False  False           False
# 31963     False      False      False  False           False
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0                  False        False              False
# 1                  False        False              False
# 2                  False        False              False
# 3                  False        False              False
# 4                  False        False              False
# ...                  ...          ...                ...
# 31959              False         True               True
# 31960              False         True               True
# 31961              False         True               True
# 31962              False         True               True
# 31963              False         True               True
#
#        calculated_host_listings_count  availability_365  \
# 0                               False             False
# 1                               False             False
# 2                               False             False
# 3                               False             False
# 4                               False             False
# ...                               ...               ...
# 31959                           False             False
# 31960                           False             False
# 31961                           False             False
# 31962                           False             False
# 31963                           False             False
#
#        number_of_reviews_ltm  license
# 0                      False     True
# 1                      False     True
# 2                      False     True
# 3                      False     True
# 4                      False     True
# ...                      ...      ...
# 31959                  False     True
# 31960                  False     True
# 31961                  False     True
# 31962                  False     True
# 31963                  False     True
#
# [31964 rows x 18 columns]

# %%
num_nulos_por_coluna_listings = listings_raw_df.isnull().sum()
print(num_nulos_por_coluna_listings)
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             3
# neighbourhood_group               31964
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        8140
# reviews_per_month                  8140
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           31964
# dtype: int64

# %%
listings_raw_df.drop_duplicates(inplace=True)

# %%
listings_raw_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31959    False
# 31960    False
# 31961    False
# 31962    False
# 31963    False
# Length: 31964, dtype: bool

# %%
listings_raw_df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  3.196400e+04  3.196400e+04  31964.000000  31964.000000   31964.000000
# mean   3.514699e+17  1.663077e+08    -22.967574    -43.251361     819.913027
# std    3.999653e+17  1.684315e+08      0.035182      0.100595    6640.141788
# min    1.787800e+04  1.671000e+03    -23.073276    -43.723009      33.000000
# 25%    2.184739e+07  2.258631e+07    -22.984820    -43.310047     196.000000
# 50%    5.261496e+07  8.693849e+07    -22.972860    -43.195670     317.000000
# 75%    7.814279e+17  3.004090e+08    -22.956165    -43.185946     600.000000
# max    9.855551e+17  5.379850e+08    -22.749690    -43.104400  562031.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    31964.000000       31964.000000       23824.000000
# mean         4.740395          19.938274           0.974190
# std         23.653482          40.676059           1.127053
# min          1.000000           0.000000           0.010000
# 25%          1.000000           0.000000           0.170000
# 50%          2.000000           4.000000           0.570000
# 75%          3.000000          20.000000           1.380000
# max       1125.000000         618.000000          14.780000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    31964.000000      31964.000000           31964.000000
# mean                         8.839319        188.491960               7.017426
# std                         23.515196        133.012558              11.436773
# min                          1.000000          0.000000               0.000000
# 25%                          1.000000         72.000000               0.000000
# 50%                          2.000000        174.000000               2.000000
# 75%                          4.000000        335.000000               9.000000
# max                        163.000000        365.000000             133.000000

# %%
listings_raw_df.head(5)
# Out:
#       id                                               name  host_id  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...    68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...   102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...   153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...    70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...   222884
#
#                   host_name neighbourhood_group neighbourhood  latitude  \
# 0                  Matthias                None    Copacabana -22.96599
# 1                   Viviane                None    Copacabana -22.97735
# 2  Patricia Miranda & Paulo                None    Copacabana -22.98107
# 3                   Goitaca                None       Ipanema -22.98591
# 4                    Marcio                None    Copacabana -22.96574
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -43.17940  Entire home/apt    279               5                301
# 1  -43.19105  Entire home/apt    330               2                272
# 2  -43.19136  Entire home/apt    192               3                446
# 3  -43.20302  Entire home/apt   3448               2                152
# 4  -43.17514  Entire home/apt    703               3                 20
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-09-11               1.87                               1
# 1  2023-09-07               1.68                               1
# 2  2023-09-11               2.82                               1
# 3  2023-09-10               0.99                               9
# 4  2023-09-10               0.20                               1
#
#    availability_365  number_of_reviews_ltm license
# 0               265                     25    None
# 1               203                     24    None
# 2                46                     37    None
# 3               306                     30    None
# 4               307                     12    None

# %%
listings_raw_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
new_name_columns_listings = ['id', 'nome', 'id_hospede', 'nome_hospede', 'grupo_bairro', 'bairro', 'latitude', 'longitude', 'tipo', 'preco', 'minimo_noites', 'numero_avaliacoes', 'ultima_avaliacao', 'avaliacoes_por_mes', 'numero_hospedes', 'disponibilidade_365', 'avaliacoes_ltm', 'licenca']

# %%
listings_raw_df.columns = new_name_columns_listings

# %%
listings_raw_df.head(5)
# Out:
#       id                                               nome  id_hospede  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...       68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...      102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...      153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...       70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...      222884
#
#                nome_hospede grupo_bairro      bairro  latitude  longitude  \
# 0                  Matthias         None  Copacabana -22.96599  -43.17940
# 1                   Viviane         None  Copacabana -22.97735  -43.19105
# 2  Patricia Miranda & Paulo         None  Copacabana -22.98107  -43.19136
# 3                   Goitaca         None     Ipanema -22.98591  -43.20302
# 4                    Marcio         None  Copacabana -22.96574  -43.17514
#
#               tipo  preco  minimo_noites  numero_avaliacoes ultima_avaliacao  \
# 0  Entire home/apt    279              5                301       2023-09-11
# 1  Entire home/apt    330              2                272       2023-09-07
# 2  Entire home/apt    192              3                446       2023-09-11
# 3  Entire home/apt   3448              2                152       2023-09-10
# 4  Entire home/apt    703              3                 20       2023-09-10
#
#    avaliacoes_por_mes  numero_hospedes  disponibilidade_365  avaliacoes_ltm  \
# 0                1.87                1                  265              25
# 1                1.68                1                  203              24
# 2                2.82                1                   46              37
# 3                0.99                9                  306              30
# 4                0.20                1                  307              12
#
#   licenca
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
listings_raw_df["ultima_avaliacao"] = pd.to_datetime(listings_raw_df["ultima_avaliacao"])

# %%
listings_raw_df.dtypes
# Out:
# id                              int64
# nome                           object
# id_hospede                      int64
# nome_hospede                   object
# grupo_bairro                   object
# bairro                         object
# latitude                      float64
# longitude                     float64
# tipo                           object
# preco                           int64
# minimo_noites                   int64
# numero_avaliacoes               int64
# ultima_avaliacao       datetime64[ns]
# avaliacoes_por_mes            float64
# numero_hospedes                 int64
# disponibilidade_365             int64
# avaliacoes_ltm                  int64
# licenca                        object
# dtype: object

# %% [markdown]
# ##### reviews

# %% [markdown]
#    - Identifique e lide com valores ausentes, duplicatas e outliers nos dados brutos da camada "bronze".

# %%
reviews_raw_df.isnull()
# Out:
#         listing_id     id   date  reviewer_id  reviewer_name  comments
# 0            False  False  False        False          False     False
# 1            False  False  False        False          False     False
# 2            False  False  False        False          False     False
# 3            False  False  False        False          False     False
# 4            False  False  False        False          False     False
# ...            ...    ...    ...          ...            ...       ...
# 637302       False  False  False        False          False     False
# 637303       False  False  False        False          False     False
# 637304       False  False  False        False          False     False
# 637305       False  False  False        False          False     False
# 637306       False  False  False        False          False     False
#
# [637307 rows x 6 columns]

# %%
num_nulos_por_coluna_reviews = reviews_raw_df.isnull().sum()
print(num_nulos_por_coluna_reviews)
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         19
# dtype: int64

# %%
reviews_raw_df.drop_duplicates(inplace=True)

# %%
reviews_raw_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 637302    False
# 637303    False
# 637304    False
# 637305    False
# 637306    False
# Length: 637307, dtype: bool

# %%
reviews_raw_df.describe()
# Out:
#          listing_id            id   reviewer_id
# count  6.373070e+05  6.373070e+05  6.373070e+05
# mean   1.128101e+17  4.469503e+17  1.852193e+08
# std    2.636175e+17  3.845078e+17  1.509693e+08
# min    1.787800e+04  5.063600e+04  5.000000e+00
# 25%    9.642367e+06  5.381218e+08  5.029380e+07
# 50%    2.702873e+07  5.578677e+17  1.499738e+08
# 75%    4.870192e+07  8.100821e+17  3.004780e+08
# max    9.825902e+17  9.862971e+17  5.381118e+08

# %%
reviews_raw_df.head(5)
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0      231497  726625  2011-11-17      1356783         Jenny
# 1       17878   64852  2010-07-15       135370           Tia
# 2       17878   76744  2010-08-11        10206          Mimi
# 3       17878   91074  2010-09-06        80253           Jan
# 4       17878  137528  2010-11-12       230449         Orene
#
#                                             comments
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...

# %%
reviews_raw_df.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
new_name_columns_reviews = ['id_listing', 'id', 'data', 'reviewer_id', 'reviewer_name','comentarios']

# %%
reviews_raw_df.columns = new_name_columns_reviews

# %%
reviews_raw_df.head(5)
# Out:
#    id_listing      id        data  reviewer_id reviewer_name  \
# 0      231497  726625  2011-11-17      1356783         Jenny
# 1       17878   64852  2010-07-15       135370           Tia
# 2       17878   76744  2010-08-11        10206          Mimi
# 3       17878   91074  2010-09-06        80253           Jan
# 4       17878  137528  2010-11-12       230449         Orene
#
#                                          comentarios
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...

# %%
reviews_raw_df["data"] = pd.to_datetime(reviews_raw_df["data"])

# %%
reviews_raw_df.dtypes
# Out:
# id_listing                int64
# id                        int64
# data             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comentarios              object
# dtype: object

# %% [markdown]
# **Data Quality - Camada Silver:**
#    - Defina métricas de qualidade de dados, como integridade, precisão e consistência para os dados da camada "bronze".
#    - Implemente verificações para garantir que os dados da camada "silver" estejam em conformidade com essas métricas.
#    - Estabeleça um sistema de monitoramento contínuo da qualidade dos dados da camada "silver".

# %% [markdown]
# ##### calendar

# %%
calendar_raw_df.head(5)
# Out:
#    id_listing       data disponibilidade    preco preco_ajustado  \
# 0       17878 2023-09-23               f  $265.00        $265.00
# 1       17878 2023-09-24               t  $265.00        $265.00
# 2       17878 2023-09-25               f  $290.00        $290.00
# 3       17878 2023-09-26               f  $290.00        $290.00
# 4       17878 2023-09-27               f  $290.00        $290.00
#
#    minimo_noites  maximo_noites
# 0            5.0           28.0
# 1            5.0           28.0
# 2            5.0           28.0
# 3            5.0           28.0
# 4            5.0           28.0

# %% [markdown]
#    - Defina métricas de qualidade de dados, como integridade, precisão e consistência para os dados da camada "bronze".

# %% [markdown]
# Verifique se há valores ausentes em cada coluna

# %%
valores_ausentes = calendar_raw_df.isnull().sum()
print(valores_ausentes)
# Out:
# id_listing         0
# data               0
# disponibilidade    0
# preco              0
# preco_ajustado     0
# minimo_noites      3
# maximo_noites      3
# dtype: int64

# %% [markdown]
# Porcentagem de registros completos

# %%
total_registros = len(calendar_raw_df)
registros_completos = calendar_raw_df.dropna().shape[0]
porcentagem_completos = (registros_completos / total_registros) * 100

print(f'Porcentagem de registros completos: {porcentagem_completos:.2f}%')
# Out:
# Porcentagem de registros completos: 100.00%

# %% [markdown]
#    - Implemente verificações para garantir que os dados da camada "silver" estejam em conformidade com essas métricas.

# %% [markdown]
# Verifique se a coluna "disponibilidade" contém apenas os valores "t" ou "f"

# %%
valores_validos = ["t", "f"]
valores_incorretos = calendar_raw_df[-calendar_raw_df["disponibilidade"].isin(valores_validos)]

if not valores_incorretos.empty:
    print("Valores incorretos encontrados na coluna 'disponibilidade':")
    print(valores_incorretos)
else:
    print("Todos os valores na coluna 'disponibilidade' são válidos.")
# Out:
# Todos os valores na coluna 'disponibilidade' são válidos.

# %% [markdown]
# Verifique se há valores ausentes em colunas críticas

# %%
colunas_criticas = ['id_listing', 'data', 'disponibilidade', 'preco', 'preco_ajustado', 'minimo_noites', 'maximo_noites']
valores_ausentes = calendar_raw_df[colunas_criticas].isnull().sum()

if valores_ausentes.any():
    print("Valores ausentes encontrados nas colunas críticas:")
    print(valores_ausentes)
else:
    print("Nenhum valor ausente nas colunas críticas.")
# Out:
# Valores ausentes encontrados nas colunas críticas:
# id_listing         0
# data               0
# disponibilidade    0
# preco              0
# preco_ajustado     0
# minimo_noites      3
# maximo_noites      3
# dtype: int64

# %% [markdown]
# ##### listings

# %%
listings_raw_df.head(5)
# Out:
#       id                                               nome  id_hospede  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...       68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...      102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...      153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...       70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...      222884
#
#                nome_hospede grupo_bairro      bairro  latitude  longitude  \
# 0                  Matthias         None  Copacabana -22.96599  -43.17940
# 1                   Viviane         None  Copacabana -22.97735  -43.19105
# 2  Patricia Miranda & Paulo         None  Copacabana -22.98107  -43.19136
# 3                   Goitaca         None     Ipanema -22.98591  -43.20302
# 4                    Marcio         None  Copacabana -22.96574  -43.17514
#
#               tipo  preco  minimo_noites  numero_avaliacoes ultima_avaliacao  \
# 0  Entire home/apt    279              5                301       2023-09-11
# 1  Entire home/apt    330              2                272       2023-09-07
# 2  Entire home/apt    192              3                446       2023-09-11
# 3  Entire home/apt   3448              2                152       2023-09-10
# 4  Entire home/apt    703              3                 20       2023-09-10
#
#    avaliacoes_por_mes  numero_hospedes  disponibilidade_365  avaliacoes_ltm  \
# 0                1.87                1                  265              25
# 1                1.68                1                  203              24
# 2                2.82                1                   46              37
# 3                0.99                9                  306              30
# 4                0.20                1                  307              12
#
#   licenca
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %% [markdown]
#    - Defina métricas de qualidade de dados, como integridade, precisão e consistência para os dados da camada "bronze".

# %% [markdown]
# Verifique se há valores ausentes em cada coluna

# %%
valores_ausentes = listings_raw_df.isnull().sum()
print(valores_ausentes)
# Out:
# id                         0
# nome                       0
# id_hospede                 0
# nome_hospede               3
# grupo_bairro           31964
# bairro                     0
# latitude                   0
# longitude                  0
# tipo                       0
# preco                      0
# minimo_noites              0
# numero_avaliacoes          0
# ultima_avaliacao        8140
# avaliacoes_por_mes      8140
# numero_hospedes            0
# disponibilidade_365        0
# avaliacoes_ltm             0
# licenca                31964
# dtype: int64

# %%
total_linhas = len(listings_raw_df.index)  
print(f'Número de linhas do DataFrame: {total_linhas}')
# Out:
# Número de linhas do DataFrame: 31964

# %% [markdown]
# Eliminação das linhas: grupo_bairro e licenca

# %%
columns_eliminate = ["grupo_bairro", "licenca"]
listings_raw_df = listings_raw_df.drop(columns_eliminate, axis=1)

# %% [markdown]
# Porcentagem de registros completos

# %%
total_registros = len(listings_raw_df)
registros_completos = listings_raw_df.dropna().shape[0]
porcentagem_completos = (registros_completos / total_registros) * 100

print(f'Porcentagem de registros completos: {porcentagem_completos:.2f}%')
# Out:
# Porcentagem de registros completos: 74.53%

# %% [markdown]
# ##### reviews

# %%
reviews_raw_df.head(5)
# Out:
#    id_listing      id       data  reviewer_id reviewer_name  \
# 0      231497  726625 2011-11-17      1356783         Jenny
# 1       17878   64852 2010-07-15       135370           Tia
# 2       17878   76744 2010-08-11        10206          Mimi
# 3       17878   91074 2010-09-06        80253           Jan
# 4       17878  137528 2010-11-12       230449         Orene
#
#                                          comentarios
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...

# %% [markdown]
#    - Defina métricas de qualidade de dados, como integridade, precisão e consistência para os dados da camada "bronze".

# %% [markdown]
# Verifique se há valores ausentes em cada coluna

# %%
valores_ausentes = reviews_raw_df.isnull().sum()
print(valores_ausentes)
# Out:
# id_listing        0
# id                0
# data              0
# reviewer_id       0
# reviewer_name     0
# comentarios      19
# dtype: int64

# %%
total_linhas = len(reviews_raw_df.index)  
print(f'Número de linhas do DataFrame: {total_linhas}')
# Out:
# Número de linhas do DataFrame: 637307

# %% [markdown]
# Porcentagem de registros completos

# %%
total_registros = len(reviews_raw_df)
registros_completos = reviews_raw_df.dropna().shape[0]
porcentagem_completos = (registros_completos / total_registros) * 100

print(f'Porcentagem de registros completos: {porcentagem_completos:.2f}%')
# Out:
# Porcentagem de registros completos: 100.00%

# %% [markdown]
# Carregamento Processing Zone

# %% [markdown]
# calendar

# %%
danilo_freitas_processing_calendar = "danilo_freitas_processing_calendar"
trusted = "trusted"

# %%
db_params = {
    "dbname": "postgres",
    "user": "postgres",
    "password": "ada_postgres_1009",
    "host": "database-ada-1009.clzgkgrmzmzh.us-east-1.rds.amazonaws.com",  
    "port": "5432"  
}

# %%
engine = create_engine(f'postgresql+psycopg2://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{db_params["dbname"]}')

# %%
calendar_raw_df.to_sql(danilo_freitas_processing_calendar, con=engine, schema=trusted, if_exists='replace', index=False)

# %% [markdown]
# listings

# %%
danilo_freitas_processing_listings = "danilo_freitas_processing_listings"
trusted = "trusted"

# %%
listings_raw_df.to_sql(danilo_freitas_processing_listings, con=engine, schema=trusted, if_exists='replace', index=False)
# Out:
# 964

# %% [markdown]
# reviews

# %%
danilo_freitas_processing_reviews = "danilo_freitas_processing_reviews"
trusted = "trusted"

# %%
reviews_raw_df.to_sql(danilo_freitas_processing_reviews, con=engine, schema=trusted, if_exists='replace', index=False)
# Out:
# 307

# %% [markdown]
# **Transformação de Dados com dbt - Camada Silver:**
#    - Utilize a ferramenta dbt para criar a camada "silver" de dados, realizando transformações e preparando os dados da camada em questão.
#    - Mantenha um controle de versão dos modelos dbt relacionados à camada "silver" e automatize a execução das transformações.

# %% [markdown]
# calendar

# %%
calendar_processing = "SELECT * FROM raw.danilo_freitas_raw_calendar;"

# %%
calendar_processing_df = pd.read_sql_query(calendar_processing, conn)
# Out:
# /tmp/ipykernel_26692/1883037361.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   calendar_processing_df = pd.read_sql_query(calendar_processing, conn)

# %%
calendar_processing_df.head(5)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-09-23         f  $265.00        $265.00             5.0
# 1       17878  2023-09-24         t  $265.00        $265.00             5.0
# 2       17878  2023-09-25         f  $290.00        $290.00             5.0
# 3       17878  2023-09-26         f  $290.00        $290.00             5.0
# 4       17878  2023-09-27         f  $290.00        $290.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0

# %% [markdown]
# listings

# %%
listings_processing = "SELECT * FROM trusted.danilo_freitas_processing_listings;"

# %%
listings_processing_df = pd.read_sql_query(listings_processing, conn)
# Out:
# /tmp/ipykernel_27787/1872804015.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   listings_processing_df = pd.read_sql_query(listings_processing, conn)

# %%
listings_processing_df.head(5)
# Out:
#       id                                               nome  id_hospede  \
# 0  17878  Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...       68997
# 1  25026  Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...      102840
# 2  35764  Loft in Rio de Janeiro · ★4.90 · 1 bedroom · 1...      153691
# 3  48305  Rental unit in Ipanema · ★4.74 · 6 bedrooms · ...       70933
# 4  48901  Rental unit in Rio · ★4.37 · 4 bedrooms · 5 be...      222884
#
#                nome_hospede      bairro  latitude  longitude             tipo  \
# 0                  Matthias  Copacabana -22.96599  -43.17940  Entire home/apt
# 1                   Viviane  Copacabana -22.97735  -43.19105  Entire home/apt
# 2  Patricia Miranda & Paulo  Copacabana -22.98107  -43.19136  Entire home/apt
# 3                   Goitaca     Ipanema -22.98591  -43.20302  Entire home/apt
# 4                    Marcio  Copacabana -22.96574  -43.17514  Entire home/apt
#
#    preco  minimo_noites  numero_avaliacoes ultima_avaliacao  \
# 0    279              5                301       2023-09-11
# 1    330              2                272       2023-09-07
# 2    192              3                446       2023-09-11
# 3   3448              2                152       2023-09-10
# 4    703              3                 20       2023-09-10
#
#    avaliacoes_por_mes  numero_hospedes  disponibilidade_365  avaliacoes_ltm
# 0                1.87                1                  265              25
# 1                1.68                1                  203              24
# 2                2.82                1                   46              37
# 3                0.99                9                  306              30
# 4                0.20                1                  307              12

# %% [markdown]
# reviews

# %%
reviews_processing = "SELECT * FROM trusted.danilo_freitas_processing_reviews;"

# %%
reviews_processing_df = pd.read_sql_query(reviews_processing, conn)
# Out:
# /tmp/ipykernel_27787/3087713142.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   reviews_processing_df = pd.read_sql_query(reviews_processing, conn)

# %%
reviews_processing_df.head(5)
# Out:
#    id_listing      id       data  reviewer_id reviewer_name  \
# 0      231497  726625 2011-11-17      1356783         Jenny
# 1       17878   64852 2010-07-15       135370           Tia
# 2       17878   76744 2010-08-11        10206          Mimi
# 3       17878   91074 2010-09-06        80253           Jan
# 4       17878  137528 2010-11-12       230449         Orene
#
#                                          comentarios
# 0  Es un apartastudio muy bien ubicado. Tiene lo ...
# 1  This apartment is in a perfect location -- two...
# 2  we had a really great experience staying in Ma...
# 3  Staying in Max appartment is like living in a ...
# 4  In general very good and reasonable price.\r<b...
